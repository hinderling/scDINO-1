# %%
import torch

# Check if CUDA is available
print(f"CUDA available: {torch.cuda.is_available()}")

# Check CUDA version
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU device: {torch.cuda.get_device_name(0)}")
    
    # Create a tensor on GPU
    x = torch.tensor([1.0, 2.0, 3.0], device='cuda')
    print(f"Tensor on GPU: {x}")
    
    # Run a simple operation
    y = x * 2
    print(f"Result of operation: {y}")
# Out:
# CUDA available: True
# CUDA version: 11.7
# GPU device: NVIDIA GeForce RTX 4090
# Tensor on GPU: tensor([1., 2., 3.], device='cuda:0')
# Result of operation: tensor([2., 4., 6.], device='cuda:0')

# %%
import torch

# Check if CUDA is available
print(f"CUDA available: {torch.cuda.is_available()}")

# Check CUDA version
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU device: {torch.cuda.get_device_name(0)}")
    
    # Create a tensor on GPU
    x = torch.tensor([1.0, 2.0, 3.0], device='cuda')
    print(f"Tensor on GPU: {x}")
    
    # Run a simple operation
    y = x * 2
    print(f"Result of operation: {y}")
# Out:
# CUDA available: True
# CUDA version: 11.7
# GPU device: NVIDIA GeForce RTX 4090
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/nbahou/miniforge3/envs/dino_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2103587/329847997.py", line 12, in <module>
#     x = torch.tensor([1.0, 2.0, 3.0], device='cuda')
# /tmp/ipykernel_2103587/329847997.py:12: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:77.)
#   x = torch.tensor([1.0, 2.0, 3.0], device='cuda')
# Tensor on GPU: tensor([1., 2., 3.], device='cuda:0')
# Result of operation: tensor([2., 4., 6.], device='cuda:0')
